# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravDC27/ml_assignments/blob/main/8_Puzzle_problem_Search_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is a test program")
# Out:
# This is a test program

# %%
import random
import resource
import time
import psutil

from collections import deque

def get_random_grid():
    numbers = list(range(1, 9))  # Numbers from 1 to 8
    numbers.append('B')  # Adding a blank space

    # Shuffle the numbers
    random.shuffle(numbers)

    # Reshape the shuffled numbers into a 3x3 grid
    grid = [numbers[i:i+3] for i in range(0, 9, 3)]

    return grid

def get_final_grid():
  numbers = list(range(1, 9))  # Numbers from 1 to 8
  numbers.append('B')  # Adding a blank space
  grid = [numbers[i:i+3] for i in range(0, 9, 3)]
  return grid

def is_goal_reachable_bfs(start_state):
    goal_state = [[1, 2, 3], [4, 5, 6], [7, 8, 'B']]
    visited = set()
    queue = deque([(start_state, 0)])  # Start state and its depth

    while queue:
        current_state, depth = queue.popleft()
        if current_state == goal_state:
            end_time = get_cpu_time()
            end_memory = get_memory_usage()
            print("GOAL state reached !!! Memory usage : "+str(end_memory)+" & CPU usage : "+str(end_time)); #+"\n\nThe visited nodes are :"+str(visited));
            return True  # Goal state is reachable

        # Find the position of the blank space ('B')
        blank_row, blank_col = None, None
        for i in range(3):
            for j in range(3):
                if current_state[i][j] == 'B':
                    blank_row, blank_col = i, j
                    break

        # Generate next possible states by moving the blank space
        possible_moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # Right, Down, Left, Up
        for dr, dc in possible_moves:
            new_row, new_col = blank_row + dr, blank_col + dc
            if 0 <= new_row < 3 and 0 <= new_col < 3:
                new_state = [list(row) for row in current_state]
                new_state[blank_row][blank_col], new_state[new_row][new_col] = new_state[new_row][new_col], new_state[blank_row][blank_col]
                new_state_tuple = tuple(tuple(row) for row in new_state)
                if new_state_tuple not in visited:
                    visited.add(new_state_tuple)
                    queue.append((new_state, depth + 1))
    end_time = get_cpu_time()
    end_memory = get_memory_usage()
    print("GOAL state could NOT be reached !!! Memory usage : "+str(end_memory)+" & CPU usage : "+str(end_time)); #+"\n\nThe visited nodes are :"+str(visited));
    return False # Goal state is not reachable

# Print the generated grid
def print_grid(grid):
   for row in grid:
    print(row);

# Function to get memory usage
def get_memory_usage():
    mem = psutil.Process().memory_info().rss
    return mem / 1024  # Convert to KB

# Function to get CPU time
def get_cpu_time():
    return time.process_time()

# Example usage
start_grid = get_random_grid();
final_grid = get_final_grid();
print("The start grid is :")
print_grid(start_grid); print("\n\n");
print("The final grid is :")
print_grid(final_grid); print("\n\n");
print("Is goal state reachable?", is_goal_reachable_bfs(start_grid))
# Out:
# The start grid is :
# [3, 6, 7]
# [2, 8, 1]
# [5, 'B', 4]
#
#
#
# The final grid is :
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 'B']
#
#
#
# GOAL state could NOT be reached !!! Memory usage : 154188.0 & CPU usage : 6.843136785
# Is goal state reachable? False

# %%
import random
import resource
import time
import psutil

from collections import deque

def get_random_grid():
    numbers = list(range(1, 9))  # Numbers from 1 to 8
    numbers.append('B')  # Adding a blank space

    # Shuffle the numbers
    random.shuffle(numbers)

    # Reshape the shuffled numbers into a 3x3 grid
    grid = [numbers[i:i+3] for i in range(0, 9, 3)]
    return grid

def get_final_grid():
  numbers = list(range(1, 9))  # Numbers from 1 to 8
  numbers.append('B')  # Adding a blank space
  grid = [numbers[i:i+3] for i in range(0, 9, 3)]
  return grid

def is_goal_reachable_bfs(start_state):
    goal_state = [[1, 2, 3], [4, 5, 6], [7, 8, 'B']]
    visited = set()
    queue = deque([(start_state, 0)])  # Start state and its depth

    while queue:
        current_state, depth = queue.popleft()
        if current_state == goal_state:
            end_time = get_cpu_time()
            end_memory = get_memory_usage()
            print("GOAL state reached !!! Memory usage : "+str(end_memory)+" & CPU usage : "+str(end_time)) #+"\n\nThe visited nodes are :"+str(visited));
            return True  # Goal state is reachable

        # Find the position of the blank space ('B')
        blank_row, blank_col = None, None
        for i in range(3):
            for j in range(3):
                if current_state[i][j] == 'B':
                    blank_row, blank_col = i, j
                    break

        # Generate next possible states by moving the blank space
        possible_moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # Right, Down, Left, Up
        for dr, dc in possible_moves:
            new_row, new_col = blank_row + dr, blank_col + dc
            if 0 <= new_row < 3 and 0 <= new_col < 3:
                new_state = [list(row) for row in current_state]
                new_state[blank_row][blank_col], new_state[new_row][new_col] = new_state[new_row][new_col], new_state[blank_row][blank_col]
                new_state_tuple = tuple(tuple(row) for row in new_state)
                if new_state_tuple not in visited:
                    visited.add(new_state_tuple)
                    queue.append((new_state, depth + 1))
    end_time = get_cpu_time()
    end_memory = get_memory_usage()
    print("GOAL state could NOT be reached !!! Memory usage : "+str(end_memory)+" & CPU usage : "+str(end_time)) #+"\n\nThe visited nodes are :"+str(visited));
    return False # Goal state is not reachable


def is_goal_reachable_dfs(start_state):
    goal_state = [[1, 2, 3], [4, 5, 6], [7, 8, 'B']]
    visited = set()
    stack = [(start_state, 0)]  # Start state and its depth

    while stack:
        current_state, depth = stack.pop()
        if current_state == goal_state:
            end_time = get_cpu_time()
            end_memory = get_memory_usage()
            print("GOAL state reached using DFS!!! Memory usage : "+str(end_memory)+" & CPU usage : "+str(end_time)); #+"\n\nThe visited nodes are :"+str(visited));
            return True  # Goal state is reachable

        # Find the position of the blank space ('B')
        blank_row, blank_col = None, None
        for i in range(3):
            for j in range(3):
                if current_state[i][j] == 'B':
                    blank_row, blank_col = i, j
                    break

        # Generate next possible states by moving the blank space
        possible_moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # Right, Down, Left, Up
        for dr, dc in possible_moves:
            new_row, new_col = blank_row + dr, blank_col + dc
            if 0 <= new_row < 3 and 0 <= new_col < 3:
                new_state = [list(row) for row in current_state]
                new_state[blank_row][blank_col], new_state[new_row][new_col] = new_state[new_row][new_col], new_state[blank_row][blank_col]
                new_state_tuple = tuple(tuple(row) for row in new_state)
                if new_state_tuple not in visited:
                    visited.add(new_state_tuple)
                    stack.append((new_state, depth + 1))
    end_time = get_cpu_time()
    end_memory = get_memory_usage()
    print("GOAL state could NOT be reached using DFS!!! Memory usage : "+str(end_memory)+" & CPU usage : "+str(end_time)); #+"\n\nThe visited nodes are :"+str(visited));
    return False  # Goal state is not reachable

# Print the generated grid
def print_grid(grid):
   for row in grid:
    print(row);

# Function to get memory usage
def get_memory_usage():
    mem = psutil.Process().memory_info().rss
    return mem / 1024  # Convert to KB

# Function to get CPU time
def get_cpu_time():
    return time.process_time()


# Example usage
start_grid = get_random_grid();
final_grid = get_final_grid();
print("The start grid is :")
print_grid(start_grid); print("\n\n");
print("The final grid is :")
print_grid(final_grid); print("\n\n");

print("Is goal state reachable using BFS?", is_goal_reachable_bfs(start_grid))

print("Is goal state reachable using DFS?", is_goal_reachable_dfs(start_grid))
# Out:
# The start grid is :
# [7, 2, 5]
# [6, 'B', 8]
# [1, 4, 3]
#
#
#
# The final grid is :
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 'B']
#
#
#
# GOAL state could NOT be reached !!! Memory usage : 160728.0 & CPU usage : 11.418994962
# Is goal state reachable using BFS? False
# GOAL state could NOT be reached using DFS!!! Memory usage : 170760.0 & CPU usage : 14.099694497
# Is goal state reachable using DFS? False
